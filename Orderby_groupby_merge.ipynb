# %%
import pandas as pd

# %%
df = pd.csv("../pythonBasics/employees.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = pd.csv("../pythonBasics/employees.csv")
#
# AttributeError: module 'pandas' has no attribute 'csv'

# %%
df_sorted = df.sort_values(by='salary')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_sorted = df.sort_values(by='salary')
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.csv("../pythonBasics/employees.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 import pandas as pd
# ----> 2 df = pd.csv("../pythonBasics/employees.csv")
#
# AttributeError: module 'pandas' has no attribute 'csv'

# %%
import pandas as pd
df = pd.read_csv("../pythonBasics/employees.csv")

# %%
import pandas as pd
df = pd.csv("employees.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 import pandas as pd
# ----> 2 df = pd.csv("employees.csv")
#
# AttributeError: module 'pandas' has no attribute 'csv'

# %%
import pandas as pd

# %%
df = pd.csv("employees.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.csv("employees.csv")
#
# AttributeError: module 'pandas' has no attribute 'csv'

# %%
df_sorted = df.sort_values(by='Salary')

# %%
df
# Out:
#     EmployeeID FirstName LastName   Department  DeptNo               JobTitle  \
# 0          101   Michael   Wilson        Sales      10          Sales Manager
# 1          102      Jane   Taylor      Finance      50      Financial Analyst
# 2          103   Michael     Hall      Support      60       Customer Support
# 3          104     Linda   Taylor      Finance      50      Financial Analyst
# 4          105   Michael      Doe      Support      60       Customer Support
# 5          106     Emily    Brown      Support      60       Customer Support
# 6          107     Sarah    Jones      Finance      50             Accountant
# 7          108     Peter    Davis      Finance      50             Accountant
# 8          109   Michael    Jones      Finance      50      Financial Analyst
# 9          110     Karen    Brown      Finance      50             Accountant
# 10         111     Peter      Doe           HR      40              Recruiter
# ...

# %%
df_sorted = df.sort_values(by='Salary')

# %%
df_sorted
# Out:
#     EmployeeID FirstName LastName   Department  DeptNo               JobTitle  \
# 3          104     Linda   Taylor      Finance      50      Financial Analyst
# 7          108     Peter    Davis      Finance      50             Accountant
# 15         116     Emily    Jones  Engineering      30      Software Engineer
# 12         113      John    Moore  Engineering      30        Systems Analyst
# 19         120     David      Doe      Finance      50      Financial Analyst
# 9          110     Karen    Brown      Finance      50             Accountant
# 16         117      John    Jones        Sales      10          Sales Manager
# 18         119     David    Brown    Marketing      20  Marketing Coordinator
# 13         114     Linda     Hall    Marketing      20  Marketing Coordinator
# 5          106     Emily    Brown      Support      60       Customer Support
# 4          105   Michael      Doe      Support      60       Customer Support
# ...

# %%
# decending order of salary

df_sorted = df.sort_values(by='Salary', ascending = False)

# %%
df_sorted
# Out:
#     EmployeeID FirstName LastName   Department  DeptNo               JobTitle  \
# 17         118     Peter    Smith      Support      60       Customer Support
# 0          101   Michael   Wilson        Sales      10          Sales Manager
# 11         112    Robert    Davis  Engineering      30      Software Engineer
# 1          102      Jane   Taylor      Finance      50      Financial Analyst
# 2          103   Michael     Hall      Support      60       Customer Support
# 10         111     Peter      Doe           HR      40              Recruiter
# 8          109   Michael    Jones      Finance      50      Financial Analyst
# 14         115     Peter    Jones        Sales      10        Sales Executive
# 6          107     Sarah    Jones      Finance      50             Accountant
# 4          105   Michael      Doe      Support      60       Customer Support
# 5          106     Emily    Brown      Support      60       Customer Support
# ...

# %%
# ascending order of department number & desceneding order of salary

df_sorted = df.sort_values(by=['DeptNo','Salary'], ascending = [True,False])

# %%
df_sorted
# Out:
#     EmployeeID FirstName LastName   Department  DeptNo               JobTitle  \
# 0          101   Michael   Wilson        Sales      10          Sales Manager
# 14         115     Peter    Jones        Sales      10        Sales Executive
# 16         117      John    Jones        Sales      10          Sales Manager
# 13         114     Linda     Hall    Marketing      20  Marketing Coordinator
# 18         119     David    Brown    Marketing      20  Marketing Coordinator
# 11         112    Robert    Davis  Engineering      30      Software Engineer
# 12         113      John    Moore  Engineering      30        Systems Analyst
# 15         116     Emily    Jones  Engineering      30      Software Engineer
# 10         111     Peter      Doe           HR      40              Recruiter
# 1          102      Jane   Taylor      Finance      50      Financial Analyst
# 8          109   Michael    Jones      Finance      50      Financial Analyst
# ...

# %%
df
# Out:
#     EmployeeID FirstName LastName   Department  DeptNo               JobTitle  \
# 0          101   Michael   Wilson        Sales      10          Sales Manager
# 1          102      Jane   Taylor      Finance      50      Financial Analyst
# 2          103   Michael     Hall      Support      60       Customer Support
# 3          104     Linda   Taylor      Finance      50      Financial Analyst
# 4          105   Michael      Doe      Support      60       Customer Support
# 5          106     Emily    Brown      Support      60       Customer Support
# 6          107     Sarah    Jones      Finance      50             Accountant
# 7          108     Peter    Davis      Finance      50             Accountant
# 8          109   Michael    Jones      Finance      50      Financial Analyst
# 9          110     Karen    Brown      Finance      50             Accountant
# 10         111     Peter      Doe           HR      40              Recruiter
# ...

# %%
# ascending order of department number & desceneding order of salary and save the changes permanently 

df.sort_values(by=['DeptNo','Salary'], ascending = [True,False],inplace=True)

# %%
df
# Out:
#     EmployeeID FirstName LastName   Department  DeptNo               JobTitle  \
# 0          101   Michael   Wilson        Sales      10          Sales Manager
# 14         115     Peter    Jones        Sales      10        Sales Executive
# 16         117      John    Jones        Sales      10          Sales Manager
# 13         114     Linda     Hall    Marketing      20  Marketing Coordinator
# 18         119     David    Brown    Marketing      20  Marketing Coordinator
# 11         112    Robert    Davis  Engineering      30      Software Engineer
# 12         113      John    Moore  Engineering      30        Systems Analyst
# 15         116     Emily    Jones  Engineering      30      Software Engineer
# 10         111     Peter      Doe           HR      40              Recruiter
# 1          102      Jane   Taylor      Finance      50      Financial Analyst
# 8          109   Michael    Jones      Finance      50      Financial Analyst
# ...

# %%
data = {'enmpno':[1,2,3],'ename': ["A","B","C"]}

# %%
data
# Out:
# {'enmpno': [1, 2, 3], 'ename': ['A', 'B', 'C']}

# %%
pd.DataFrame(data)
# Out:
#    enmpno ename
# 0       1     A
# 1       2     B
# 2       3     C

# %%
df= pd.DataFrame(data, index = [3,1,2])

# %%
df.sort_values(by=index,ascending=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df.sort_values(by=index,ascending=True)
#
# NameError: name 'index' is not defined

# %%
df.sort_index(ascending=False)
# Out:
#    enmpno ename
# 3       1     A
# 2       3     C
# 1       2     B

# %%
df = pd.read_csv("employees.csv")

# %%
df
# Out:
#     EmployeeID FirstName LastName   Department  DeptNo               JobTitle  \
# 0          101   Michael   Wilson        Sales      10          Sales Manager
# 1          102      Jane   Taylor      Finance      50      Financial Analyst
# 2          103   Michael     Hall      Support      60       Customer Support
# 3          104     Linda   Taylor      Finance      50      Financial Analyst
# 4          105   Michael      Doe      Support      60       Customer Support
# 5          106     Emily    Brown      Support      60       Customer Support
# 6          107     Sarah    Jones      Finance      50             Accountant
# 7          108     Peter    Davis      Finance      50             Accountant
# 8          109   Michael    Jones      Finance      50      Financial Analyst
# 9          110     Karen    Brown      Finance      50             Accountant
# 10         111     Peter      Doe           HR      40              Recruiter
# ...

# %%
df_grouped = df.groupby('DeptNo')['EmployeeID'].count().reset_index()

# %%
df_grouped
# Out:
#    DeptNo  EmployeeID
# 0      10           3
# 1      20           2
# 2      30           3
# 3      40           1
# 4      50           7
# 5      60           4

# %%
#Rename
df_grouped.rename(columns={"EmployeeID":"CountOfEmp"})
# Out:
#    DeptNo  CountOfEmp
# 0      10           3
# 1      20           2
# 2      30           3
# 3      40           1
# 4      50           7
# 5      60           4

# %%
df.groupby('DeptNO')['Salary'].agg(['max','min','count','sum'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.groupby('DeptNO')['Salary'].agg(['max','min','count','sum'])
#
# File C:\python313\Lib\site-packages\pandas\core\frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
#    9198     observed=observed,
#    9199     dropna=dropna,
#    9200 )
#
# ...

# %%
import pandas as pd
df = pd.csv("employees.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df = pd.csv("employees.csv")
#
# AttributeError: module 'pandas' has no attribute 'csv'

# %%
df

# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv")

# %%
df
# Out:
#     EmployeeID FirstName LastName   Department  DeptNo               JobTitle  \
# 0          101   Michael   Wilson        Sales      10          Sales Manager
# 1          102      Jane   Taylor      Finance      50      Financial Analyst
# 2          103   Michael     Hall      Support      60       Customer Support
# 3          104     Linda   Taylor      Finance      50      Financial Analyst
# 4          105   Michael      Doe      Support      60       Customer Support
# 5          106     Emily    Brown      Support      60       Customer Support
# 6          107     Sarah    Jones      Finance      50             Accountant
# 7          108     Peter    Davis      Finance      50             Accountant
# 8          109   Michael    Jones      Finance      50      Financial Analyst
# 9          110     Karen    Brown      Finance      50             Accountant
# 10         111     Peter      Doe           HR      40              Recruiter
# ...

# %%
df.groupby('DeptNo')['Salary'].agg(['max','min','count','sum'])
# Out:
#           max    min  count     sum
# DeptNo
# 10      98396  74212      3  260235
# 20      79333  74429      2  153762
# 30      92989  53196      3  208185
# 40      90803  90803      1   90803
# 50      92116  50229      7  508595
# 60      99157  83619      4  358456

# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv")

# %%
Filter = df['DeptNo'] == 50

# %%
Fdf[Filter]
# Out:
#     EmployeeID FirstName LastName Department  DeptNo           JobTitle  \
# 1          102      Jane   Taylor    Finance      50  Financial Analyst
# 3          104     Linda   Taylor    Finance      50  Financial Analyst
# 6          107     Sarah    Jones    Finance      50         Accountant
# 7          108     Peter    Davis    Finance      50         Accountant
# 8          109   Michael    Jones    Finance      50  Financial Analyst
# 9          110     Karen    Brown    Finance      50         Accountant
# 19         120     David      Doe    Finance      50  Financial Analyst
#
#     Salary    HireDate
# 1    92116  2022-06-19
# 3    50229  2019-07-26
# 6    86274  2021-11-19
# 7    52380  2018-09-25
# 8    88608  2021-08-06
# 9    70811  2019-10-22
# 19   68177  2019-06-07

# %%
df_Filter_10_20 = (df['DeptNo'] == 10) & (df['DeptNo'] == 20)

# %%
df[df_Filter_10_20 ]
# Out:
# Empty DataFrame
# Columns: [EmployeeID, FirstName, LastName, Department, DeptNo, JobTitle, Salary, HireDate]
# Index: []

# %%
df_grouped = df.groupby('DeptNo')['EmployeeID'].count().reset_index()

# %%
df_grouped
# Out:
#    DeptNo  EmployeeID
# 0      10           3
# 1      20           2
# 2      30           3
# 3      40           1
# 4      50           7
# 5      60           4

# %%
filter_having = df_grouped['EmployeeID'].apply(lambda x:x>3)

# %%
df_grouped[filter_having].reset_index()
# Out:
#    index  DeptNo  EmployeeID
# 0      4      50           7
# 1      5      60           4

# %%
# Merge

# %%
df = pd.read_csv("../pythonBasics/salaries.csv")

# %%
df1 = pd.read_csv("../pythonBasics/EmpName.csv")

# %%
df1
# Out:
#    eno     Name
# 0  101    Alice
# 1  102      Bob
# 2  103  Charlie
# 3  104    David
# 4  105      Eva

# %%
df.merge(df1,left_on = 'empno',right_on = 'eno',how = 'inner')
# Out:
#    empno  salary  eno     Name
# 0    101   50000  101    Alice
# 1    102   60000  102      Bob
# 2    103   55000  103  Charlie
# 3    104   65000  104    David
# 4    105   70000  105      Eva

# %%
df
# Out:
#    empno  salary
# 0    101   50000
# 1    102   60000
# 2    103   55000
# 3    104   65000
# 4    105   70000

# %%
df.merge(df1,left_on = 'empno',right_on = 'eno',how = 'right')
# Out:
#    empno   salary  eno     Name
# 0  101.0  50000.0  101    Alice
# 1  102.0  60000.0  102      Bob
# 2  103.0  55000.0  103  Charlie
# 3  104.0  65000.0  104    David
# 4  105.0  70000.0  105      Eva
# 5    NaN      NaN  106      Rak
# 6    NaN      NaN  107     keta

# %%
df1
# Out:
#    eno     Name
# 0  101    Alice
# 1  102      Bob
# 2  103  Charlie
# 3  104    David
# 4  105      Eva
# 5  106      Rak
# 6  107     keta

# %%
df
# Out:
#    empno  salary
# 0    101   50000
# 1    102   60000
# 2    103   55000
# 3    104   65000
# 4    105   70000
